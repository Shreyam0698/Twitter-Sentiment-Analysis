# %%
import pandas as pd

df = pd.read_csv('/Users/shreyamchaudhary/Downloads/twitter_sentiment.csv')

# %%
df.head()
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
df = df.iloc[:, [2, 3]].reset_index(drop=True)

# %%
df.columns = ['sentiment', 'text']

# %%
df.head()
# Out:
#   sentiment                                               text
# 0  Positive  I am coming to the borders and I will kill you...
# 1  Positive  im getting on borderlands and i will kill you ...
# 2  Positive  im coming on borderlands and i will murder you...
# 3  Positive  im getting on borderlands 2 and i will murder ...
# 4  Positive  im getting into borderlands and i can murder y...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75681 entries, 0 to 75680
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sentiment  75681 non-null  object
#  1   text       74995 non-null  object
# dtypes: object(2)
# memory usage: 1.2+ MB

# %%
print(df.shape)
# Out:
# (75681, 2)

# %%
df.isnull().sum()
df.dropna(inplace=True)

# %%
sum(df['text'].apply(len) > 5), sum(df['text'].apply(len) <= 5)
# Out:
# (72882, 2113)

# %%
print(df.shape)
df = df[df['text'].apply(len) > 5]
print(df.shape)
# Out:
# (74995, 2)
# (72882, 2)

# %%
df['sentiment'].value_counts()
# Out:
# sentiment
# Negative      22020
# Positive      20185
# Neutral       17899
# Irrelevant    12778
# Name: count, dtype: int64

# %% [markdown]
# ### Preprocessing preprocess_Kgptalkie Package

# %%
import preprocess_kgptalkie as ps

df.columns
# Out:
# Index(['sentiment', 'text'], dtype='object')

# %%
df = ps.get_basic_features(df)

# %%
df.columns
# Out:
# Index(['sentiment', 'text', 'char_counts', 'word_counts', 'avg_wordlength',
#        'stopwords_counts', 'hashtag_counts', 'mentions_counts',
#        'digits_counts', 'uppercase_counts'],
#       dtype='object')

# %%
df.head()
# Out:
#   sentiment                                               text  char_counts  \
# 0  Positive  I am coming to the borders and I will kill you...           40
# 1  Positive  im getting on borderlands and i will kill you ...           41
# 2  Positive  im coming on borderlands and i will murder you...           42
# 3  Positive  im getting on borderlands 2 and i will murder ...           46
# 4  Positive  im getting into borderlands and i can murder y...           44
#
#    word_counts  avg_wordlength  stopwords_counts  hashtag_counts  \
# 0           12        3.333333                 6               0
# 1           10        4.100000                 5               0
# 2           10        4.200000                 5               0
# 3           12        3.833333                 6               0
# 4           10        4.400000                 5               0
#
#    mentions_counts  digits_counts  uppercase_counts
# 0                0              1                 2
# 1                0              1                 0
# 2                0              1                 0
# 3                0              2                 0
# 4                0              1                 0

# %%
# Data visualization 
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
num_cols = df.select_dtypes(include='number').columns

for index, col in enumerate(num_cols):
    plt.subplot(2, 4, index+1) 
    sns.kdeplot(data=df, x = col, hue='sentiment', fill=False)
plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
df['sentiment'].value_counts().plot(kind = 'pie', autopct = "%1.0f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Wordcloud visulization

# %%
from wordcloud import WordCloud, STOPWORDS

stopwods = list(STOPWORDS)

stopwods
# Out:
# ['can',
#  'each',
#  'as',
#  'most',
#  'she',
#  "aren't",
#  'in',
#  "i'm",
#  'against',
#  'by',
#  "let's",
#  "why's",
#  'yourselves',
#  'those',
#  "hasn't",
#  'would',
#  'her',
#  'otherwise',
#  'ours',
#  'and',
#  "he'll",
#  'www',
#  'them',
#  'being',
#  "didn't",
#  'few',
#  'me',
#  'which',
#  "we're",
#  "that's",
#  'have',
#  'when',
#  'once',
#  'hers',
#  "what's",
#  'yours',
#  "they'd",
#  'k',
#  'like',
#  'some',
#  'themselves',
#  'him',
#  'however',
#  'had',
#  'between',
#  'does',
#  'doing',
#  'having',
#  "we'd",
#  "here's",
#  'it',
#  'they',
#  'not',
#  'from',
#  'but',
#  "it's",
#  'such',
#  'these',
#  'their',
#  'after',
#  'himself',
#  'was',
#  "he's",
#  'further',
#  'on',
#  'through',
#  'are',
#  'very',
#  'whom',
#  "couldn't",
#  'hence',
#  'should',
#  "they're",
#  'all',
#  "weren't",
#  "you're",
#  "she'll",
#  'with',
#  'more',
#  'com',
#  'itself',
#  'did',
#  'ought',
#  "haven't",
#  'during',
#  'then',
#  'why',
#  "you've",
#  "i'll",
#  'here',
#  'same',
#  "shan't",
#  "isn't",
#  'or',
#  'you',
#  'where',
#  'than',
#  "he'd",
#  'herself',
#  "you'll",
#  'own',
#  'myself',
#  'we',
#  "wouldn't",
#  "they'll",
#  'this',
#  "you'd",
#  'could',
#  'only',
#  'therefore',
#  "i'd",
#  'my',
#  'shall',
#  'off',
#  'until',
#  "shouldn't",
#  "can't",
#  'how',
#  'just',
#  "where's",
#  'both',
#  'am',
#  'http',
#  'get',
#  'about',
#  'r',
#  'cannot',
#  'theirs',
#  'again',
#  'his',
#  'also',
#  'before',
#  "who's",
#  "won't",
#  'since',
#  "we'll",
#  'be',
#  "how's",
#  "i've",
#  'up',
#  'for',
#  'other',
#  'an',
#  'out',
#  "don't",
#  'over',
#  'that',
#  'ourselves',
#  'its',
#  'down',
#  "doesn't",
#  'ever',
#  'what',
#  'our',
#  'been',
#  'above',
#  'the',
#  'of',
#  'because',
#  "hadn't",
#  "we've",
#  'while',
#  "wasn't",
#  'who',
#  'into',
#  'to',
#  "mustn't",
#  "there's",
#  'do',
#  "she's",
#  "when's",
#  'yourself',
#  'he',
#  'there',
#  'below',
#  'were',
#  'is',
#  "they've",
#  'no',
#  'at',
#  'else',
#  'your',
#  'so',
#  'under',
#  'a',
#  "she'd",
#  'too',
#  'has',
#  'nor',
#  'any',
#  'i',
#  'if']

# %%
wordcloud = WordCloud(background_color='white', stopwords=stopwods, 
                      max_words=300, max_font_size=40, scale=5).generate(str(df['text']))
plt.imshow(wordcloud)

# %%
plt.figure(figsize=(40,20))

for index, sent in enumerate(df['sentiment'].unique()):
    plt.subplot(2, 2, index+1)

    data = df[df['sentiment'] == sent]['text']
    wordcloud = WordCloud(background_color='white', stopwords=stopwods, 
                      max_words=300, max_font_size=40, scale=5).generate(str(data))
    plt.imshow(wordcloud)
    plt.xticks([])
    plt.yticks([])
    plt.title(sent, fontsize = 40)

# %% [markdown]
# ### Data Cleaning

# %%
df['text'] = df['text'].apply(lambda x: x.lower())
df['text'] = df['text'].apply(lambda x: ps.remove_urls(x))
df['text'] = df['text'].apply(lambda x: ps.remove_html_tags(x))
df['text'] = df['text'].apply(lambda x: ps.remove_rt(x))
df['text'] = df['text'].apply(lambda x: ps.remove_special_chars(x))
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/preprocess_kgptalkie/utils.py:97: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   return BeautifulSoup(x, 'lxml').get_text().strip()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((58305,), (14577,))

# %% [markdown]
# ### Model Building and Testing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
clf = Pipeline([('Tfidf', TfidfVectorizer(stop_words=stopwods)), 
                ('rfc', RandomForestClassifier(n_jobs=-1))])

# %%
clf.fit(X_train, Y_train)
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['aren', 'couldn', 'didn', 'doesn', 'don', 'hadn', 'hasn', 'haven', 'isn', 'let', 'll', 'mustn', 're', 'shan', 'shouldn', 've', 'wasn', 'weren', 'won', 'wouldn'] not in stop_words.
#   warnings.warn(
# Pipeline(steps=[('Tfidf',
#                  TfidfVectorizer(stop_words=['can', 'each', 'as', 'most', 'she',
#                                              "aren't", 'in', "i'm", 'against',
#                                              'by', "let's", "why's",
#                                              'yourselves', 'those', "hasn't",
#                                              'would', 'her', 'otherwise',
#                                              'ours', 'and', "he'll", 'www',
#                                              'them', 'being', "didn't", 'few',
#                                              'me', 'which', "we're", "that's", ...])),
#                 ('rfc', RandomForestClassifier(n_jobs=-1))])

# %% [markdown]
# ## Evaluation

# %%
from sklearn.metrics import classification_report
y_pred = clf.predict(X_test)
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant       0.96      0.87      0.91      2487
#     Negative       0.93      0.95      0.94      4517
#      Neutral       0.93      0.91      0.92      3581
#     Positive       0.89      0.94      0.92      3992
#
#     accuracy                           0.92     14577
#    macro avg       0.93      0.92      0.92     14577
# weighted avg       0.93      0.92      0.92     14577

# %%
import pickle
pickle.dump(clf, open("twitter_sentiment.pkl", 'wb'))

# %% [markdown]
# ## Testing

# %%
clf.predict(["Feeling completely drained today Nothing's going right and it seems like the universe is against me "])
# Out:
# array(['Positive'], dtype=object)
